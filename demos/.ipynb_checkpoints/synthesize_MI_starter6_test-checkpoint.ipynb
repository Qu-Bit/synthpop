# %%
# %load_ext autoreload
# %autoreload 2
from synthpop.recipes.starter6 import Starter
starter_ver='6'

from output_verify import output_verify
from synthpop.synthesizer import synthesize_all, enable_logging 
import pandas as pd
import os,time
import pickle

outputfolder='/home/da/tools/synthpop/demos/outputs/'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Synthesize by county

# %%
#for whole county
time0=time.time()
results=[]
def synthesize_counties(counties):
    for county in counties:
        for phase in range(3):
            pathout=outputfolder+county+"_starter%s_"%(starter_ver)
            starter = Starter(os.environ["CENSUS"], "MI", county, phase=phase)
            households, persons, fit, marginals=synthesize_all(starter)

            households.index.name='hh_id' #result[0] is hh
            households['serialno'] = households['serialno'].map(lambda x: '%f' % x)
            persons['serialno'] = persons['serialno'].map(lambda x: '%f' % x)
            #results[0].to_csv(outputfolder+county+"_starter%s_"%('3')+"HHs.csv",float_format='%.f') #float_format, not use scentific, pplies to all fp numbers 
            #could use results['serialno'] = results['serialno'].map(lambda x: '%f' % x) to change output format for serialno only
            households.to_csv(pathout+'_households.csv')
            persons.to_csv(pathout+'_persons.csv')

            df_verify=output_verify(households,persons,marginals)
            df_verify[0].to_csv(pathout+"_verify_households.csv")
            df_verify[1].to_csv(pathout+"_verify_persons.csv")
            df_verify[2].to_csv(pathout+"_verify_hh_size.csv")
            if phase == 0:
                df_verify[3].to_csv("hh7_persons_drawing.csv")
            if phase == 1:
                #df_ttlpersons=pd.DataFrame(data=[totalpersons],columns=['hh_size_person_factor'])
                df_verify[4].to_csv("hh_size_person_factor.csv")
            if phase == 2:
                os.rename("hh7_persons_drawing.csv", pathout+"_hh7_persons_drawing.csv")
                os.rename("hh_size_person_factor.csv", pathout+"_hh_size_person_factor.csv")

            with open(pathout+'_fit_stats.pkl', 'wb') as f:
                pickle.dump(fit, f)
            print time.time()-time0
    return households, persons, fit, marginals
#synthesize_counties(["Livingston County","Oakland County","Washtenaw County","Wayne County","Monroe County","Macomb County"])
res=synthesize_counties(["Macomb County"])
# Out:
# Synthesizing at geog level: 'block_group' (number of geographies is 627)
# Synthesizing geog id:
# state              26
# county            099
# tract          206700
# block group         1
# dtype: object
# Drawing 749 households
# Synthesizing geog id:
# state              26
# county            099
# tract          206700
# block group         2
# dtype: object
# Drawing 783 households
# Synthesizing geog id:
# state              26
# county            099
# tract          210000
# block group         1
# dtype: object
# Drawing 722 households
# Synthesizing geog id:
# state              26
# county            099
# tract          210000
# block group         2
# dtype: object
# Drawing 737 households
# Synthesizing geog id:
# state              26
# county            099
# tract          211000
# block group         1
# dtype: object
# Drawing 722 households
# Synthesizing geog id:
# state              26
# county            099
# tract          211000
# block group         2
# dtype: object
# Drawing 467 households
# Synthesizing geog id:
# state              26
# county            099
# tract          211000
# block group         3
# dtype: object
# Drawing 1178 households
# Synthesizing geog id:
# state              26
# county            099
# tract          212000
# block group         1
# dtype: object
# Drawing 648 households
# Synthesizing geog id:
# state              26
# county            099
# tract          212000
# block group         2
# dtype: object
# Drawing 1091 households
# Synthesizing geog id:
# state              26
# county            099
# tract          212000
# block group         3
# dtype: object
# Drawing 220 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214000
# block group         1
# dtype: object
# Drawing 400 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214000
# block group         2
# dtype: object
# Drawing 187 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214000
# block group         3
# dtype: object
# Drawing 274 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214500
# block group         1
# dtype: object
# Drawing 290 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214500
# block group         2
# dtype: object
# Drawing 189 households
# Synthesizing geog id:
# state              26
# county            099
# tract          214500
# block group         3
# dtype: object
# Drawing 995 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215000
# block group         1
# dtype: object
# Drawing 460 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215000
# block group         2
# dtype: object
# Drawing 522 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215000
# block group         3
# dtype: object
# Drawing 849 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215200
# block group         1
# dtype: object
# Drawing 714 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215200
# block group         2
# dtype: object
# Drawing 1114 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215200
# block group         3
# dtype: object
# Drawing 505 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215200
# block group         4
# dtype: object
# Drawing 336 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215300
# block group         1
# dtype: object
# Drawing 788 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215300
# block group         2
# dtype: object
# Drawing 891 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215500
# block group         1
# dtype: object
# Drawing 700 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215500
# block group         2
# dtype: object
# Drawing 793 households
# Synthesizing geog id:
# state              26
# county            099
# tract          215500
# block group         3
# dtype: object
# Drawing 1045 households
# Synthesizing geog id:
# state              26
# county            099
# tract          216000
# block group         1
# dtype: object
# Drawing 637 households
# Synthesizing geog id:
# state              26
# county            099
# tract          216000
# block group         2
# dtype: object
# Drawing 882 households
# Synthesizing geog id:
# state              26
# county            099
# tract          217000
# block group         1
# dtype: object
# Drawing 740 households
# Synthesizing geog id:
# state              26
# county            099
# tract          217000
# block group         2
# dtype: object
# Drawing 432 households
# Synthesizing geog id:
# state              26
# county            099
# tract          218000
# block group         1
# dtype: object
# Drawing 535 households
# Synthesizing geog id:
# state              26
# county            099
# tract          218000
# block group         2
# dtype: object
# Drawing 883 households
# Synthesizing geog id:
# state              26
# county            099
# tract          218000
# block group         3
# dtype: object
# Drawing 677 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220001
# block group         1
# dtype: object
# Drawing 690 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220001
# block group         2
# dtype: object
# Drawing 302 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220001
# block group         3
# dtype: object
# Drawing 1648 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220002
# block group         1
# dtype: object
# Drawing 357 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220002
# block group         2
# dtype: object
# Drawing 649 households
# Synthesizing geog id:
# state              26
# county            099
# tract          220002
# block group         3
# dtype: object
# Drawing 831 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221100
# block group         1
# dtype: object
# Drawing 1113 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221100
# block group         2
# dtype: object
# Drawing 278 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221100
# block group         3
# dtype: object
# Drawing 1152 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221200
# block group         1
# dtype: object
# Drawing 766 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221200
# block group         2
# dtype: object
# Drawing 144 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221200
# block group         3
# dtype: object
# Drawing 591 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221200
# block group         4
# dtype: object
# Drawing 1014 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221500
# block group         1
# dtype: object
# Drawing 411 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221800
# block group         1
# dtype: object
# Drawing 1017 households
# Synthesizing geog id:
# state              26
# county            099
# tract          221800
# block group         2
# dtype: object
# Drawing 644 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222101
# block group         1
# dtype: object
# Drawing 994 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222101
# block group         2
# dtype: object
# Drawing 908 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222102
# block group         1
# dtype: object
# Drawing 1677 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222102
# block group         2
# dtype: object
# Drawing 758 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222102
# block group         3
# dtype: object
# Drawing 766 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222500
# block group         1
# dtype: object
# Drawing 469 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222500
# block group         2
# dtype: object
# Drawing 1050 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222800
# block group         1
# dtype: object
# Drawing 735 households
# Synthesizing geog id:
# state              26
# county            099
# tract          222800
# block group         2
# dtype: object
# Drawing 476 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223400
# block group         1
# dtype: object
# Drawing 803 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223400
# block group         2
# dtype: object
# Drawing 2250 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223500
# block group         1
# dtype: object
# Drawing 555 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223800
# block group         1
# dtype: object
# Drawing 774 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223800
# block group         2
# dtype: object
# Drawing 2678 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223800
# block group         3
# dtype: object
# Drawing 677 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223900
# block group         1
# dtype: object
# Drawing 878 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223900
# block group         2
# dtype: object
# Drawing 966 households
# Synthesizing geog id:
# state              26
# county            099
# tract          223900
# block group         3
# dtype: object
# Drawing 1196 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224000
# block group         1
# dtype: object
# Drawing 1128 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224000
# block group         2
# dtype: object
# Drawing 1184 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224000
# block group         3
# dtype: object
# Drawing 1495 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224100
# block group         1
# dtype: object
# Drawing 1194 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224100
# block group         2
# dtype: object
# Drawing 1387 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224200
# block group         1
# dtype: object
# Drawing 1210 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224200
# block group         2
# dtype: object
# Drawing 938 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224200
# block group         3
# dtype: object
# Drawing 752 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224300
# block group         1
# dtype: object
# Drawing 775 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224300
# block group         2
# dtype: object
# Drawing 873 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224400
# block group         1
# dtype: object
# Drawing 708 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224400
# block group         2
# dtype: object
# Drawing 502 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224400
# block group         3
# dtype: object
# Drawing 522 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224500
# block group         1
# dtype: object
# Drawing 865 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224500
# block group         2
# dtype: object
# Drawing 861 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224600
# block group         1
# dtype: object
# Drawing 1283 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224600
# block group         2
# dtype: object
# Drawing 474 households
# Synthesizing geog id:
# state              26
# county            099
# tract          224600
# block group         3
# dtype: object
# Drawing 713 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225100
# block group         1
# dtype: object
# Drawing 636 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225100
# block group         2
# dtype: object
# Drawing 471 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225200
# block group         1
# dtype: object
# Drawing 1095 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225200
# block group         2
# dtype: object
# Drawing 486 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225200
# block group         3
# dtype: object
# Drawing 571 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225300
# block group         1
# dtype: object
# Drawing 335 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225300
# block group         2
# dtype: object
# Drawing 308 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225300
# block group         3
# dtype: object
# Drawing 295 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225300
# block group         4
# dtype: object
# Drawing 1024 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225400
# block group         1
# dtype: object
# Drawing 1244 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225400
# block group         2
# dtype: object
# Drawing 1082 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225400
# block group         3
# dtype: object
# Drawing 457 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225500
# block group         1
# dtype: object
# Drawing 920 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225500
# block group         2
# dtype: object
# Drawing 432 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225500
# block group         3
# dtype: object
# Drawing 619 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225600
# block group         1
# dtype: object
# Drawing 716 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225600
# block group         2
# dtype: object
# Drawing 499 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225600
# block group         3
# dtype: object
# Drawing 661 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225701
# block group         1
# dtype: object
# Drawing 722 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225701
# block group         2
# dtype: object
# Drawing 941 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225701
# block group         3
# dtype: object
# Drawing 917 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225702
# block group         1
# dtype: object
# Drawing 257 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225702
# block group         2
# dtype: object
# Drawing 370 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225800
# block group         1
# dtype: object
# Drawing 629 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225800
# block group         2
# dtype: object
# Drawing 805 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225800
# block group         3
# dtype: object
# Drawing 408 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225800
# block group         4
# dtype: object
# Drawing 564 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225900
# block group         1
# dtype: object
# Drawing 757 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225900
# block group         2
# dtype: object
# Drawing 827 households
# Synthesizing geog id:
# state              26
# county            099
# tract          225900
# block group         3
# dtype: object
# Drawing 290 households
# Synthesizing geog id:
# state              26
# county            099
# tract          226100
# block group         1
# dtype: object
# Drawing 1257 households
# Synthesizing geog id:
# state              26
# county            099
# tract          226100
# block group         2
# dtype: object
# Drawing 1212 households
# Synthesizing geog id:
# state              26
# county            099
# tract          226400
# block group         1
# dtype: object
# Drawing 746 households
# Synthesizing geog id:
# state              26
# county            099
# tract          226700
# block group         1
# dtype: object
# Drawing 777 households
# Synthesizing geog id:
# state              26
# county            099
# tract          226700
# block group         2
# dtype: object
# Drawing 1136 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227000
# block group         1
# dtype: object
# Drawing 1218 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227000
# block group         2
# dtype: object
# Drawing 305 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227000
# block group         3
# dtype: object
# Drawing 425 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227000
# block group         4
# dtype: object
# Drawing 639 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227300
# block group         1
# dtype: object
# Drawing 531 households
# Synthesizing geog id:
# state              26
# county            099
# tract          227300
# block group         2
# dtype: object
# Drawing 1349 households
# Synthesizing geog id:
# state              26
# county            099
# tract          228000
# block group         1
# dtype: object
# Drawing 1059 households
# Synthesizing geog id:
# state              26
# county            099
# tract          228000
# block group         2
# dtype: object
# Drawing 418 households
# Synthesizing geog id:
# state              26
# county            099
# tract          228100
# block group         1
# dtype: object
# Drawing 351 households
# Synthesizing geog id:
# state              26
# county            099
# tract          228100
# block group         2
# dtype: object
# Drawing 331 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230000
# block group         1
# dtype: object
# Drawing 915 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230000
# block group         2
# dtype: object
# Drawing 1290 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230200
# block group         1
# dtype: object
# Drawing 311 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230200
# block group         2
# dtype: object
# Drawing 576 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230200
# block group         3
# dtype: object
# Drawing 314 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230200
# block group         4
# dtype: object
# Drawing 684 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230300
# block group         1
# dtype: object
# Drawing 733 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230300
# block group         2
# dtype: object
# Drawing 332 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230300
# block group         3
# dtype: object
# Drawing 540 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230400
# block group         1
# dtype: object
# Drawing 760 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230400
# block group         2
# dtype: object
# Drawing 380 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230400
# block group         3
# dtype: object
# Drawing 281 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230500
# block group         1
# dtype: object
# Drawing 275 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230500
# block group         2
# dtype: object
# Drawing 767 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230500
# block group         3
# dtype: object
# Drawing 54 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230500
# block group         4
# dtype: object
# Drawing 645 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230601
# block group         1
# dtype: object
# Drawing 1809 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230601
# block group         2
# dtype: object
# Drawing 1131 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230602
# block group         1
# dtype: object
# Drawing 928 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230602
# block group         2
# dtype: object
# Drawing 1135 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230700
# block group         1
# dtype: object
# Drawing 854 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230700
# block group         2
# dtype: object
# Drawing 406 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230700
# block group         3
# dtype: object
# Drawing 406 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230800
# block group         1
# dtype: object
# Drawing 683 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230800
# block group         2
# dtype: object
# Drawing 371 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230800
# block group         3
# dtype: object
# Drawing 529 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230900
# block group         1
# dtype: object
# Drawing 246 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230900
# block group         2
# dtype: object
# Drawing 1367 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230900
# block group         3
# dtype: object
# Drawing 671 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230900
# block group         4
# dtype: object
# Drawing 228 households
# Synthesizing geog id:
# state              26
# county            099
# tract          230900
# block group         5
# dtype: object
# Drawing 452 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231000
# block group         1
# dtype: object
# Drawing 668 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231000
# block group         2
# dtype: object
# Drawing 303 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231000
# block group         3
# dtype: object
# Drawing 579 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231100
# block group         1
# dtype: object
# Drawing 680 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231100
# block group         2
# dtype: object
# Drawing 841 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231200
# block group         1
# dtype: object
# Drawing 518 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231200
# block group         2
# dtype: object
# Drawing 531 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231200
# block group         3
# dtype: object
# Drawing 522 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231400
# block group         1
# dtype: object
# Drawing 551 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231400
# block group         2
# dtype: object
# Drawing 735 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231400
# block group         3
# dtype: object
# Drawing 584 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231500
# block group         1
# dtype: object
# Drawing 433 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231500
# block group         2
# dtype: object
# Drawing 638 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231500
# block group         3
# dtype: object
# Drawing 533 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231500
# block group         4
# dtype: object
# Drawing 154 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231600
# block group         1
# dtype: object
# Drawing 732 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231600
# block group         2
# dtype: object
# Drawing 925 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231600
# block group         3
# dtype: object
# Drawing 312 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231700
# block group         1
# dtype: object
# Drawing 1035 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231700
# block group         2
# dtype: object
# Drawing 502 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231700
# block group         3
# dtype: object
# Drawing 480 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231800
# block group         1
# dtype: object
# Drawing 665 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231800
# block group         2
# dtype: object
# Drawing 376 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231800
# block group         3
# dtype: object
# Drawing 487 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231900
# block group         1
# dtype: object
# Drawing 636 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231900
# block group         2
# dtype: object
# Drawing 433 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231900
# block group         3
# dtype: object
# Drawing 897 households
# Synthesizing geog id:
# state              26
# county            099
# tract          231900
# block group         4
# dtype: object
# Drawing 265 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232000
# block group         1
# dtype: object
# Drawing 200 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232000
# block group         2
# dtype: object
# Drawing 583 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232100
# block group         1
# dtype: object
# Drawing 1035 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232100
# block group         2
# dtype: object
# Drawing 1233 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232100
# block group         3
# dtype: object
# Drawing 477 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232200
# block group         1
# dtype: object
# Drawing 324 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232200
# block group         2
# dtype: object
# Drawing 348 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232200
# block group         3
# dtype: object
# Drawing 468 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232200
# block group         4
# dtype: object
# Drawing 370 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232200
# block group         5
# dtype: object
# Drawing 455 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232300
# block group         1
# dtype: object
# Drawing 966 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232300
# block group         2
# dtype: object
# Drawing 982 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232300
# block group         3
# dtype: object
# Drawing 6 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232400
# block group         1
# dtype: object
# Drawing 460 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232400
# block group         2
# dtype: object
# Drawing 599 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232400
# block group         3
# dtype: object
# Drawing 326 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232400
# block group         4
# dtype: object
# Drawing 697 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232500
# block group         1
# dtype: object
# Drawing 833 households
# Synthesizing geog id:
# state              26
# county            099
# tract          232500
# block group         2
# dtype: object
# Drawing 702 households
# Synthesizing geog id:
# state              26
# county            099
# tract          233000
# block group         1
# dtype: object
# Drawing 763 households
# Synthesizing geog id:
# state              26
# county            099
# tract          233000
# block group         2
# dtype: object
# Drawing 783 households
# Synthesizing geog id:
# state              26
# county            099
# tract          233000
# block group         3
# dtype: object
# Drawing 604 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240000
# block group         1
# dtype: object
# Drawing 830 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240000
# block group         2
# dtype: object
# Drawing 842 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240300
# block group         1
# dtype: object
# Drawing 1125 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240300
# block group         2
# dtype: object
# Drawing 701 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240400
# block group         1
# dtype: object
# Drawing 938 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240400
# block group         2
# dtype: object
# Drawing 648 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240400
# block group         3
# dtype: object
# Drawing 219 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240400
# block group         4
# dtype: object
# Drawing 540 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240500
# block group         1
# dtype: object
# Drawing 429 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240500
# block group         2
# dtype: object
# Drawing 581 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240600
# block group         1
# dtype: object
# Drawing 523 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240600
# block group         2
# dtype: object
# Drawing 852 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240600
# block group         3
# dtype: object
# Drawing 532 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240600
# block group         4
# dtype: object
# Drawing 999 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240700
# block group         1
# dtype: object
# Drawing 620 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240700
# block group         2
# dtype: object
# Drawing 269 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240700
# block group         3
# dtype: object
# Drawing 322 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240700
# block group         4
# dtype: object
# Drawing 400 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240800
# block group         1
# dtype: object
# Drawing 681 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240800
# block group         2
# dtype: object
# Drawing 1123 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240800
# block group         3
# dtype: object
# Drawing 1001 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240900
# block group         1
# dtype: object
# Drawing 296 households
# Synthesizing geog id:
# state              26
# county            099
# tract          240900
# block group         2
# dtype: object
# Drawing 496 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241000
# block group         1
# dtype: object
# Drawing 290 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241000
# block group         2
# dtype: object
# Drawing 366 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241000
# block group         3
# dtype: object
# Drawing 670 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241000
# block group         4
# dtype: object
# Drawing 776 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241200
# block group         1
# dtype: object
# Drawing 425 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241200
# block group         2
# dtype: object
# Drawing 266 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241200
# block group         3
# dtype: object
# Drawing 733 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241200
# block group         4
# dtype: object
# Drawing 240 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241200
# block group         5
# dtype: object
# Drawing 266 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241300
# block group         1
# dtype: object
# Drawing 1036 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241400
# block group         1
# dtype: object
# Drawing 501 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241400
# block group         2
# dtype: object
# Drawing 963 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241500
# block group         1
# dtype: object
# Drawing 1732 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241600
# block group         1
# dtype: object
# Drawing 378 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241600
# block group         2
# dtype: object
# Drawing 639 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241700
# block group         1
# dtype: object
# Drawing 217 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241700
# block group         2
# dtype: object
# Drawing 856 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241700
# block group         3
# dtype: object
# Drawing 613 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241800
# block group         1
# dtype: object
# Drawing 570 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241800
# block group         2
# dtype: object
# Drawing 737 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241800
# block group         3
# dtype: object
# Drawing 903 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241900
# block group         1
# dtype: object
# Drawing 765 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241900
# block group         2
# dtype: object
# Drawing 535 households
# Synthesizing geog id:
# state              26
# county            099
# tract          241900
# block group         3
# dtype: object
# Drawing 719 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242000
# block group         1
# dtype: object
# Drawing 668 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242000
# block group         2
# dtype: object
# Drawing 2525 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242100
# block group         1
# dtype: object
# Drawing 850 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242100
# block group         2
# dtype: object
# Drawing 570 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242500
# block group         1
# dtype: object
# Drawing 1021 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242500
# block group         2
# dtype: object
# Drawing 996 households
# Synthesizing geog id:
# state              26
# county            099
# tract          242500
# block group         3
# dtype: object
# Drawing 773 households
# Synthesizing geog id:
# state              26
# county            099
# tract          243000
# block group         1
# dtype: object
# Drawing 1068 households
# Synthesizing geog id:
# state              26
# county            099
# tract          243000
# block group         2
# dtype: object
# Drawing 673 households
# Synthesizing geog id:
# state              26
# county            099
# tract          243500
# block group         1
# dtype: object
# Drawing 1548 households
# Synthesizing geog id:
# state              26
# county            099
# tract          243500
# block group         2
# dtype: object
# Drawing 1020 households
# Synthesizing geog id:
# state              26
# county            099
# tract          244000
# block group         1
# dtype: object
# Drawing 837 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245000
# block group         1
# dtype: object
# Drawing 248 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245000
# block group         2
# dtype: object
# Drawing 877 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245000
# block group         3
# dtype: object
# Drawing 362 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245000
# block group         4
# dtype: object
# Drawing 302 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245100
# block group         1
# dtype: object
# Drawing 458 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245100
# block group         2
# dtype: object
# Drawing 358 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245100
# block group         3
# dtype: object
# Drawing 369 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245100
# block group         4
# dtype: object
# Drawing 478 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245200
# block group         1
# dtype: object
# Drawing 302 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245200
# block group         2
# dtype: object
# Drawing 479 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         1
# dtype: object
# Drawing 483 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         2
# dtype: object
# Drawing 261 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         3
# dtype: object
# Drawing 377 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         4
# dtype: object
# Drawing 260 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         5
# dtype: object
# Drawing 352 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245300
# block group         6
# dtype: object
# Drawing 264 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245400
# block group         1
# dtype: object
# Drawing 436 households
# Synthesizing geog id:
# state              26
# county            099
# tract          245400
# block group         2
# dtype: object
# Drawing 209 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247100
# block group         1
# dtype: object
# Drawing 447 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247200
# block group         1
# dtype: object
# Drawing 557 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247200
# block group         2
# dtype: object
# Drawing 1213 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247200
# block group         3
# dtype: object
# Drawing 455 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247200
# block group         4
# dtype: object
# Drawing 627 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247300
# block group         1
# dtype: object
# Drawing 762 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247300
# block group         2
# dtype: object
# Drawing 369 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247300
# block group         3
# dtype: object
# Drawing 798 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247300
# block group         4
# dtype: object
# Drawing 779 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247400
# block group         1
# dtype: object
# Drawing 307 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247400
# block group         2
# dtype: object
# Drawing 333 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247400
# block group         3
# dtype: object
# Drawing 417 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247500
# block group         1
# dtype: object
# Drawing 250 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247500
# block group         2
# dtype: object
# Drawing 585 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247601
# block group         1
# dtype: object
# Drawing 996 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247602
# block group         1
# dtype: object
# Drawing 738 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247602
# block group         2
# dtype: object
# Drawing 714 households
# Synthesizing geog id:
# state              26
# county            099
# tract          247602
# block group         3
# dtype: object
# Drawing 651 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250000
# block group         1
# dtype: object
# Drawing 259 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250000
# block group         2
# dtype: object
# Drawing 324 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250000
# block group         3
# dtype: object
# Drawing 319 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250100
# block group         1
# dtype: object
# Drawing 192 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250100
# block group         2
# dtype: object
# Drawing 394 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250100
# block group         3
# dtype: object
# Drawing 343 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250200
# block group         1
# dtype: object
# Drawing 240 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250200
# block group         2
# dtype: object
# Drawing 523 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250200
# block group         3
# dtype: object
# Drawing 403 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250300
# block group         1
# dtype: object
# Drawing 575 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250300
# block group         2
# dtype: object
# Drawing 384 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250300
# block group         3
# dtype: object
# Drawing 510 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250400
# block group         1
# dtype: object
# Drawing 606 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250500
# block group         1
# dtype: object
# Drawing 258 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250500
# block group         2
# dtype: object
# Drawing 416 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250500
# block group         3
# dtype: object
# Drawing 280 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250600
# block group         1
# dtype: object
# Drawing 521 households
# Synthesizing geog id:
# state              26
# county            099
# tract          250600
# ...
# Synthesizing geog id:
# state              26
# county            099
# tract          255000
# block group         2
# dtype: object
# Drawing 799 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255000
# block group         3
# dtype: object
# Drawing 783 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255000
# block group         4
# dtype: object
# Drawing 147 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255100
# block group         1
# dtype: object
# Drawing 530 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255100
# block group         2
# dtype: object
# Drawing 282 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255100
# block group         3
# dtype: object
# Drawing 417 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255200
# block group         1
# dtype: object
# Drawing 387 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255200
# block group         2
# dtype: object
# Drawing 1464 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255300
# block group         1
# dtype: object
# Drawing 360 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255300
# block group         2
# dtype: object
# Drawing 245 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255300
# block group         3
# dtype: object
# Drawing 342 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255300
# block group         4
# dtype: object
# Drawing 290 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255300
# block group         5
# dtype: object
# Drawing 546 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255400
# block group         1
# dtype: object
# Drawing 226 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255400
# block group         2
# dtype: object
# Drawing 393 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255400
# block group         3
# dtype: object
# Drawing 369 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255500
# block group         1
# dtype: object
# Drawing 276 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255500
# block group         2
# dtype: object
# Drawing 395 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255600
# block group         1
# dtype: object
# Drawing 390 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255600
# block group         2
# dtype: object
# Drawing 272 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255600
# block group         3
# dtype: object
# Drawing 318 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255600
# block group         4
# dtype: object
# Drawing 328 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255700
# block group         1
# dtype: object
# Drawing 350 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255700
# block group         2
# dtype: object
# Drawing 272 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255800
# block group         1
# dtype: object
# Drawing 371 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255800
# block group         2
# dtype: object
# Drawing 265 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255800
# block group         3
# dtype: object
# Drawing 313 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255900
# block group         1
# dtype: object
# Drawing 296 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255900
# block group         2
# dtype: object
# Drawing 193 households
# Synthesizing geog id:
# state              26
# county            099
# tract          255900
# block group         3
# dtype: object
# Drawing 263 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256000
# block group         1
# dtype: object
# Drawing 264 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256000
# block group         2
# dtype: object
# Drawing 692 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256100
# block group         1
# dtype: object
# Drawing 376 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256100
# block group         2
# dtype: object
# Drawing 265 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256100
# block group         3
# dtype: object
# Drawing 231 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256100
# block group         4
# dtype: object
# Drawing 262 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256200
# block group         1
# dtype: object
# Drawing 404 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256200
# block group         2
# dtype: object
# Drawing 338 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256300
# block group         1
# dtype: object
# Drawing 405 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256300
# block group         2
# dtype: object
# Drawing 347 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256400
# block group         1
# dtype: object
# Drawing 238 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256400
# block group         2
# dtype: object
# Drawing 310 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256500
# block group         1
# dtype: object
# Drawing 330 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256500
# block group         2
# dtype: object
# Drawing 250 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256600
# block group         1
# dtype: object
# Drawing 190 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256600
# block group         2
# dtype: object
# Drawing 365 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256600
# block group         3
# dtype: object
# Drawing 307 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256600
# block group         4
# dtype: object
# Drawing 548 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256700
# block group         1
# dtype: object
# Drawing 416 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256700
# block group         2
# dtype: object
# Drawing 268 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256800
# block group         1
# dtype: object
# Drawing 280 households
# Synthesizing geog id:
# state              26
# county            099
# tract          256800
# block group         2
# dtype: object
# Drawing 360 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258000
# block group         1
# dtype: object
# Drawing 340 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258000
# block group         2
# dtype: object
# Drawing 433 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258000
# block group         3
# dtype: object
# Drawing 318 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258100
# block group         1
# dtype: object
# Drawing 407 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258100
# block group         2
# dtype: object
# Drawing 529 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258100
# block group         3
# dtype: object
# Drawing 243 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258100
# block group         4
# dtype: object
# Drawing 262 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258200
# block group         1
# dtype: object
# Drawing 561 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258200
# block group         2
# dtype: object
# Drawing 529 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258300
# block group         1
# dtype: object
# Drawing 561 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258300
# block group         2
# dtype: object
# Drawing 515 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258400
# block group         1
# dtype: object
# Drawing 620 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258400
# block group         2
# dtype: object
# Drawing 441 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258400
# block group         3
# dtype: object
# Drawing 421 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258400
# block group         4
# dtype: object
# Drawing 293 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258400
# block group         5
# dtype: object
# Drawing 219 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258500
# block group         1
# dtype: object
# Drawing 336 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258500
# block group         2
# dtype: object
# Drawing 247 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258500
# block group         3
# dtype: object
# Drawing 159 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258600
# block group         1
# dtype: object
# Drawing 264 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258600
# block group         2
# dtype: object
# Drawing 218 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258600
# block group         3
# dtype: object
# Drawing 378 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258600
# block group         4
# dtype: object
# Drawing 483 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258600
# block group         5
# dtype: object
# Drawing 353 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258700
# block group         1
# dtype: object
# Drawing 361 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258700
# block group         2
# dtype: object
# Drawing 352 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258700
# block group         3
# dtype: object
# Drawing 235 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258800
# block group         1
# dtype: object
# Drawing 328 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258800
# block group         2
# dtype: object
# Drawing 364 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258800
# block group         3
# dtype: object
# Drawing 331 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258800
# block group         4
# dtype: object
# Drawing 390 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258900
# block group         1
# dtype: object
# Drawing 236 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258900
# block group         2
# dtype: object
# Drawing 238 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258900
# block group         3
# dtype: object
# Drawing 254 households
# Synthesizing geog id:
# state              26
# county            099
# tract          258900
# block group         4
# dtype: object
# Drawing 145 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260000
# block group         1
# dtype: object
# Drawing 388 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260000
# block group         2
# dtype: object
# Drawing 604 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260000
# block group         3
# dtype: object
# Drawing 272 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260100
# block group         1
# dtype: object
# Drawing 581 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260100
# block group         2
# dtype: object
# Drawing 403 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260100
# block group         3
# dtype: object
# Drawing 335 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260200
# block group         1
# dtype: object
# Drawing 321 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260200
# block group         2
# dtype: object
# Drawing 374 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260200
# block group         3
# dtype: object
# Drawing 209 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260300
# block group         1
# dtype: object
# Drawing 354 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260300
# block group         2
# dtype: object
# Drawing 485 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260300
# block group         3
# dtype: object
# Drawing 360 households
# Synthesizing geog id:
# state              26
# county            099
# tract          260400
# block group         1
# dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-347f1dc99d18> in <module>()
#      35     return households, persons, fit, marginals
#      36 #synthesize_counties(["Livingston County","Oakland County","Washtenaw County","Wayne County","Monroe County","Macomb County"])
# ---> 37 res=synthesize_counties(["Macomb County"])
#
# <ipython-input-6-347f1dc99d18> in synthesize_counties(counties)
#       7             pathout=outputfolder+county+"_starter%s_"%(starter_ver)
#       8             starter = Starter(os.environ["CENSUS"], "MI", county, phase=phase)
# ----> 9             households, persons, fit, marginals=synthesize_all(starter)
#      10
#      11             households.index.name='hh_id' #result[0] is hh
#
# /home/da/anaconda2/lib/python2.7/site-packages/SynthPop-0.1.dev0-py2.7.egg/synthpop/synthesizer.pyc in synthesize_all(recipe, num_geogs, indexes, marginal_zero_sub, jd_zero_sub)
#     156                 orig_hh_size,
#     157                 tar=max(p_marg.groupby(level=0).sum()) *
# --> 158                     recipe.get_hh_size_person_factor(geog_id),
#     159                 w=np.array(recipe.get_hh_size_weight(geog_id)))
#     160
#
# ValueError: cannot convert float NaN to integer

# %% [markdown]
# # Synthesize by selected BGs

# %%
households
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-16031f1ad8d5> in <module>()
# ----> 1 households
#
# NameError: name 'households' is not defined

# %%
###for selected BGs
#enable_logging()
time0=time.time()
geoname="problembgs.csv"
pathout=outputfolder+geoname+"_starter%s_"%(starter_ver)

dfbg=pd.read_csv(geoname,index_col=None,dtype=str) #make sure csv column in text not number, so read as'099' not 99
indd=[ind for i, ind in dfbg.iterrows()]
for phase in range(3):
    print "\nphase = ", phase, "\n"
    starter = Starter(os.environ["CENSUS"], "MI", 'Macomb County', phase=phase)
    households, persons, fit, marginals = synthesize_all(starter, indexes=indd)
    print fit
    #HHs and Persons output
    households.to_csv(pathout+'_households.csv')
    persons.to_csv(pathout+'_persons.csv')
    
    df_verify=output_verify(households,persons,marginals)
    df_verify[0].to_csv(pathout+"_verify_households.csv")
    df_verify[1].to_csv(pathout+"_verify_persons.csv")
    df_verify[2].to_csv(pathout+"_verify_hh_size.csv")
    if phase == 0:
        df_verify[3].to_csv("hh7_persons_drawing.csv")
    if phase == 1:
        #df_ttlpersons=pd.DataFrame(data=[totalpersons],columns=['hh_size_person_factor'])
        df_verify[4].to_csv("hh_size_person_factor.csv")
    if phase == 2:
        os.rename("hh7_persons_drawing.csv", pathout+"_hh7_persons_drawing.csv")
        os.rename("hh_size_person_factor.csv", pathout+"_hh_size_person_factor.csv")

print time.time()-time0
